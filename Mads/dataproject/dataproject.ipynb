# %% [markdown]
# # Data Project

# %% [markdown]
# Install the DST api-data reader and the pandas_datareader.

# %%
# The DST API wrapper
# %pip install git+https://github.com/alemartinello/dstapi

# A wrapper for multiple APIs with a pandas interface
# %pip install pandas-datareader
# Out:
# Collecting git+https://github.com/alemartinello/dstapi
#   Cloning https://github.com/alemartinello/dstapi to /private/var/folders/rp/8b9m7ytn6zv_75m2zj88jl7m0000gn/T/pip-req-build-1755b6f_
#   Running command git clone --filter=blob:none --quiet https://github.com/alemartinello/dstapi /private/var/folders/rp/8b9m7ytn6zv_75m2zj88jl7m0000gn/T/pip-req-build-1755b6f_
#   Resolved https://github.com/alemartinello/dstapi to commit d9eeb5a82cbc70b7d63b2ff44d92632fd77123a4
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /Users/mads/anaconda3/lib/python3.11/site-packages (from dstapi==0.2) (2.1.4)
# Requirement already satisfied: requests in /Users/mads/anaconda3/lib/python3.11/site-packages (from dstapi==0.2) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas->dstapi==0.2) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas->dstapi==0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas->dstapi==0.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas->dstapi==0.2) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mads/anaconda3/lib/python3.11/site-packages (from requests->dstapi==0.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mads/anaconda3/lib/python3.11/site-packages (from requests->dstapi==0.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mads/anaconda3/lib/python3.11/site-packages (from requests->dstapi==0.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mads/anaconda3/lib/python3.11/site-packages (from requests->dstapi==0.2) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/mads/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->dstapi==0.2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas-datareader in /Users/mads/anaconda3/lib/python3.11/site-packages (0.10.0)
# Requirement already satisfied: lxml in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas-datareader) (4.9.3)
# Requirement already satisfied: pandas>=0.23 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas-datareader) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/mads/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mads/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mads/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mads/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mads/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/mads/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Imports and set magics:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from dstapi import DstApi # install with `pip install git+https://github.com/alemartinello/dstapi`
import pandas_datareader # install with `pip install pandas-datareader`

# %% [markdown]
# # Read and clean data

# %% [markdown]
# Consider the following dictionary definitions:

# %%
columns_dict = {}
columns_dict['TRANSMID'] = 'vehicle'
columns_dict['TID'] = 'year'
columns_dict['INDHOLD'] = 'value'

# %% [markdown]
# We will download all data from table PKM1 and ...  using DstApi. First we will read and clean data from table PKM1.

# %%
pkm1_api = DstApi('PKM1') # loading the data, by writting the table name inside the paranthesis
params = pkm1_api._define_base_params(language='en') # we have no restriction, only that we eant the table in english

pkm1 = pkm1_api.get_data(params=params) #getting the data, where we in params defined, what we wanted to include from the table.
pkm1.head()
# Out:
#                                 TRANSMID   TID INDHOLD
# 0             VEHICLES ON THE ROAD TOTAL  1981      ..
# 1           Bicycles/Mopeds max. 30 km/h  1981      ..
# 2                   Motor vehicles total  1981   46168
# 3  Private cars and vans under 2.001 kg.  1981   36854
# 4                    Vans over 2.000 kg.  1981    3795

# %% [markdown]
# Rename column 'TRANSMID' to 'vehicle'

# %%
pkm1.rename(columns=columns_dict,inplace=True)
pkm1.head(14)
# Out:
#                                   vehicle  year  value
# 0              VEHICLES ON THE ROAD TOTAL  1981     ..
# 1            Bicycles/Mopeds max. 30 km/h  1981     ..
# 2                    Motor vehicles total  1981  46168
# 3   Private cars and vans under 2.001 kg.  1981  36854
# 4                     Vans over 2.000 kg.  1981   3795
# 5                                   Taxis  1981    441
# 6                             Motorcycles  1981    282
# 7                     Mopeds max. 45 km/h  1981      0
# 8                 Buses and coaches total  1981   4797
# 9                         Scheduled buses  1981   2418
# 10                Coaches and other buses  1981   2379
# 11                                  Train  1981   4724
# 12                                   Ship  1981     ..
# 13                              Aeroplane  1981     ..

# %% [markdown]
# The dataset contains following vehicles, which do not fit into our analysis, therefor they are droped.

# %%
# Build up a logical index I
I = pkm1.vehicle.str.contains('VEHICLES ON THE ROAD TOTAL')
I |= pkm1.vehicle.str.contains('Motor vehicles total')
I |= pkm1.vehicle.str.contains('Vans over 2.000 kg.')
I |= pkm1.vehicle.str.contains('Scheduled buses')
I |= pkm1.vehicle.str.contains('Coaches and other buses')
pkm1.loc[I, :]

pkm1 = pkm1.loc[I == False] # keep everything else
pkm1.reset_index(inplace = True, drop = True) # Drop old index too
pkm1.head(9)
# Out:
#                                  vehicle  year  value
# 0           Bicycles/Mopeds max. 30 km/h  1980     ..
# 1  Private cars and vans under 2.001 kg.  1980  38027
# 2                Buses and coaches total  1980   4611
# 3                                  Train  1980   4503
# 4                              Aeroplane  1980     ..
# 5                    Mopeds max. 45 km/h  1980      0
# 6                                   Ship  1980     ..
# 7                                  Taxis  1980    458
# 8                            Motorcycles  1980    275

# %% [markdown]
# Futhermore we want to restrict the years without any information, maybee

# %% [markdown]
# Sort by year and vehicle

# %%
pkm1.sort_values(by=['vehicle', 'year'],inplace=True)
pkm1.head(43)
# Out:
#        vehicle  year value
# 4    Aeroplane  1980    ..
# 14   Aeroplane  1981    ..
# 23   Aeroplane  1982    ..
# 27   Aeroplane  1983    ..
# 37   Aeroplane  1984    ..
# 52   Aeroplane  1985    ..
# 60   Aeroplane  1986    ..
# 68   Aeroplane  1987    ..
# 77   Aeroplane  1988    ..
# 81   Aeroplane  1989    ..
# 92   Aeroplane  1990   476
# 103  Aeroplane  1991   442
# 115  Aeroplane  1992   457
# 124  Aeroplane  1993   449
# 131  Aeroplane  1994   478
# 140  Aeroplane  1995   497
# 146  Aeroplane  1996   541
# 159  Aeroplane  1997   519
# 166  Aeroplane  1998   424
# 176  Aeroplane  1999   398
# 185  Aeroplane  2000   363
# 194  Aeroplane  2001   338
# 205  Aeroplane  2002   304
# 211  Aeroplane  2003   285
# 222  Aeroplane  2004   308
# 228  Aeroplane  2005   316
# 238  Aeroplane  2006   342
# 248  Aeroplane  2007   377
# 252  Aeroplane  2008   372
# 269  Aeroplane  2009   381
# 274  Aeroplane  2010   470
# 284  Aeroplane  2011   459
# 291  Aeroplane  2012   367
# 302  Aeroplane  2013   359
# 306  Aeroplane  2014   368
# 322  Aeroplane  2015   357
# 327  Aeroplane  2016   381
# 334  Aeroplane  2017   354
# 343  Aeroplane  2018   345
# 353  Aeroplane  2019   324
# 367  Aeroplane  2020   137
# 377  Aeroplane  2021   188
# 381  Aeroplane  2022   270

# %% [markdown]
# # Merge with population data from Denmark Statistics

# %% [markdown]
# We want to have the value (mio. personkm) from the PKM1 table in per capita terms. To get that, we would need to download population data from Denmark Statistics:

# %%
FT_api = DstApi('FT')
params = FT_api._define_base_params(language='en')
params['variables'][0]['values'] = ['000'] 
## 000 is the code for all of Denmark, this can be seen by using: FT_api.variable_levels('HOVEDDELE', language='en')
pop = FT_api.get_data(params=params)

pop.rename(columns={'TID':'year','INDHOLD':'population'},inplace=True)
pop =  pop.loc[:,['year','population']]
pop.head()
# Out:
#    year  population
# 0  2010     5534738
# 1  1769      797584
# 2  1840     1289075
# 3  1860     1608362
# 4  1901     2449540

# %%
merged = pd.merge(pkm1,pop,how='left',on=['year'])
merged.head(43)
# Out:
#       vehicle  year value  population
# 0   Aeroplane  1980    ..     5122065
# 1   Aeroplane  1981    ..     5123989
# 2   Aeroplane  1982    ..     5119155
# 3   Aeroplane  1983    ..     5116464
# 4   Aeroplane  1984    ..     5112130
# 5   Aeroplane  1985    ..     5111108
# 6   Aeroplane  1986    ..     5116273
# 7   Aeroplane  1987    ..     5124794
# 8   Aeroplane  1988    ..     5129254
# 9   Aeroplane  1989    ..     5129778
# 10  Aeroplane  1990   476     5135409
# 11  Aeroplane  1991   442     5146469
# 12  Aeroplane  1992   457     5162126
# 13  Aeroplane  1993   449     5180614
# 14  Aeroplane  1994   478     5196642
# 15  Aeroplane  1995   497     5215718
# 16  Aeroplane  1996   541     5251027
# 17  Aeroplane  1997   519     5275121
# 18  Aeroplane  1998   424     5294860
# 19  Aeroplane  1999   398     5313577
# 20  Aeroplane  2000   363     5330020
# 21  Aeroplane  2001   338     5349212
# 22  Aeroplane  2002   304     5368354
# 23  Aeroplane  2003   285     5383507
# 24  Aeroplane  2004   308     5397640
# 25  Aeroplane  2005   316     5411405
# 26  Aeroplane  2006   342     5427459
# 27  Aeroplane  2007   377     5447084
# 28  Aeroplane  2008   372     5475791
# 29  Aeroplane  2009   381     5511451
# 30  Aeroplane  2010   470     5534738
# 31  Aeroplane  2011   459     5560628
# 32  Aeroplane  2012   367     5580516
# 33  Aeroplane  2013   359     5602628
# 34  Aeroplane  2014   368     5627235
# 35  Aeroplane  2015   357     5659715
# 36  Aeroplane  2016   381     5707251
# 37  Aeroplane  2017   354     5748769
# 38  Aeroplane  2018   345     5781190
# 39  Aeroplane  2019   324     5806081
# 40  Aeroplane  2020   137     5822763
# 41  Aeroplane  2021   188     5840045
# 42  Aeroplane  2022   270     5873420
